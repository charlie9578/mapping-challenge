# %%
import re

import pandas as pd
import numpy as np

from bokeh.plotting import figure
from bokeh.io import show, output_notebook
output_notebook()

from map01_helpers import get_om_wind_turbines, plot_points
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="a5e4ef00-32f5-4b5c-9d57-2362396fc12b">Loading BokehJS ...</span>
#     </div>

# %%
area_Whitelee = "(55.61,-4.46,55.76,-4.05)"

# %%
try:
    df_turbines = pd.read_csv("whitelee.csv")
except:
    turbines = get_om_wind_turbines(area=area_Whitelee)
    df_turbines = pd.json_normalize(turbines['elements'])
    df_turbines.to_csv("whitelee.csv")

print(df_turbines)
# Out:
#      Unnamed: 0  type           id        lat       lon tags.generator:method  \
# 0             0  node    917143850  55.754008 -4.162368          wind_turbine
# 1             1  node   1210840754  55.709544 -4.340662          wind_turbine
# 2             2  node   1210840811  55.691094 -4.232058          wind_turbine
# 3             3  node   2029840477  55.648528 -4.325159          wind_turbine
# 4             4  node   2029840482  55.648699 -4.315897          wind_turbine
# ..          ...   ...          ...        ...       ...                   ...
# 276         276  node   8847868452  55.626942 -4.057746          wind_turbine
# 277         277  node   8847868454  55.624649 -4.053341          wind_turbine
# 278         278  node   8847868455  55.619490 -4.054581          wind_turbine
# 279         279  node   8847868510  55.612038 -4.109144          wind_turbine
# 280         280  node  10665622738  55.708713 -4.082593          wind_turbine
#
#     tags.generator:source tags.operator tags.power  \
# 0                    wind    Ecotricity  generator
# 1                    wind           NaN  generator
# 2                    wind           NaN  generator
# 3                    wind           NaN  generator
# 4                    wind           NaN  generator
# ..                    ...           ...        ...
# 276                  wind           NaN  generator
# 277                  wind           NaN  generator
# 278                  wind           NaN  generator
# 279                  wind           NaN  generator
# 280                  wind           NaN  generator
#
#     tags.generator:output:electricity tags.generator:type tags.name  \
# 0                                 NaN                 NaN       NaN
# 1                              2.3 MW     horizontal_axis        40
# 2                                 NaN     horizontal_axis       104
# 3                              2.3 MW     horizontal_axis      D169
# 4                              2.3 MW     horizontal_axis      C165
# ..                                ...                 ...       ...
# 276                               yes     horizontal_axis       NaN
# 277                               yes     horizontal_axis       NaN
# 278                               yes     horizontal_axis       NaN
# 279                               yes     horizontal_axis       NaN
# 280                               NaN                 NaN       NaN
#
#     tags.source tags.generator:model  tags.height tags.operator:wikidata  \
# 0           NaN                  NaN          NaN                    NaN
# 1        survey                  NaN          NaN                    NaN
# 2        survey                  NaN          NaN                    NaN
# 3          bing                  NaN          NaN                    NaN
# 4          bing                  NaN          NaN                    NaN
# ..          ...                  ...          ...                    ...
# 276         NaN                  NaN          NaN                    NaN
# 277         NaN                  NaN          NaN                    NaN
# 278         NaN                  NaN          NaN                    NaN
# 279         NaN                  NaN          NaN                    NaN
# 280         NaN                  NaN          NaN                    NaN
#
#     tags.manufacturer tags.model
# 0                 NaN        NaN
# 1                 NaN        NaN
# 2                 NaN        NaN
# 3                 NaN        NaN
# 4                 NaN        NaN
# ..                ...        ...
# 276               NaN        NaN
# 277               NaN        NaN
# 278               NaN        NaN
# 279               NaN        NaN
# 280               NaN        NaN
#
# [281 rows x 18 columns]

# %%
df_turbines_expanded = df_turbines.rename(columns=lambda x: re.sub(':','_',x))
df_turbines_expanded = df_turbines_expanded.rename(columns=lambda x: re.sub('tags.','',x))

required_columns = set(["source","generator_output_electricity","start_date","height_hub","generator_type","rotor_diameter","manufacturer","model"])
missing_columns = list(required_columns - set(df_turbines_expanded.columns))

# %%
df_turbines_expanded[missing_columns] = np.nan

# %%
df_turbines_expanded
# Out:
#      Unnamed_ 0  type           id        lat       lon generator_method  \
# 0             0  node    917143850  55.754008 -4.162368     wind_turbine
# 1             1  node   1210840754  55.709544 -4.340662     wind_turbine
# 2             2  node   1210840811  55.691094 -4.232058     wind_turbine
# 3             3  node   2029840477  55.648528 -4.325159     wind_turbine
# 4             4  node   2029840482  55.648699 -4.315897     wind_turbine
# ..          ...   ...          ...        ...       ...              ...
# 276         276  node   8847868452  55.626942 -4.057746     wind_turbine
# 277         277  node   8847868454  55.624649 -4.053341     wind_turbine
# 278         278  node   8847868455  55.619490 -4.054581     wind_turbine
# 279         279  node   8847868510  55.612038 -4.109144     wind_turbine
# 280         280  node  10665622738  55.708713 -4.082593     wind_turbine
#
#     generator_source    operator      power generator_output_electricity  ...  \
# 0               wind  Ecotricity  generator                          NaN  ...
# 1               wind         NaN  generator                       2.3 MW  ...
# 2               wind         NaN  generator                          NaN  ...
# 3               wind         NaN  generator                       2.3 MW  ...
# 4               wind         NaN  generator                       2.3 MW  ...
# ..               ...         ...        ...                          ...  ...
# 276             wind         NaN  generator                          yes  ...
# 277             wind         NaN  generator                          yes  ...
# 278             wind         NaN  generator                          yes  ...
# 279             wind         NaN  generator                          yes  ...
# 280             wind         NaN  generator                          NaN  ...
#
#      name  source generator_model height  operator_wikidata manufacturer  \
# 0     NaN     NaN             NaN    NaN                NaN          NaN
# 1      40  survey             NaN    NaN                NaN          NaN
# 2     104  survey             NaN    NaN                NaN          NaN
# 3    D169    bing             NaN    NaN                NaN          NaN
# 4    C165    bing             NaN    NaN                NaN          NaN
# ..    ...     ...             ...    ...                ...          ...
# 276   NaN     NaN             NaN    NaN                NaN          NaN
# 277   NaN     NaN             NaN    NaN                NaN          NaN
# 278   NaN     NaN             NaN    NaN                NaN          NaN
# 279   NaN     NaN             NaN    NaN                NaN          NaN
# 280   NaN     NaN             NaN    NaN                NaN          NaN
#
#     model rotor_diameter  start_date  height_hub
# 0     NaN            NaN         NaN         NaN
# 1     NaN            NaN         NaN         NaN
# 2     NaN            NaN         NaN         NaN
# 3     NaN            NaN         NaN         NaN
# 4     NaN            NaN         NaN         NaN
# ..    ...            ...         ...         ...
# 276   NaN            NaN         NaN         NaN
# 277   NaN            NaN         NaN         NaN
# 278   NaN            NaN         NaN         NaN
# 279   NaN            NaN         NaN         NaN
# 280   NaN            NaN         NaN         NaN
#
# [281 rows x 21 columns]

# %%
df_turbines_expanded["data_rank_colour"] = "sienna"
df_turbines_expanded["data_rank"] = "bronze"

# %%
gold_data_list = ["source","generator_output_electricity","start_date","height_hub","generator_type","rotor_diameter","manufacturer","model"]
silver_data_list = ["height_hub","rotor_diameter"]

# %%
df_turbines_expanded[silver_data_list].isnull().sum(axis=1)

df_turbines_expanded.loc[df_turbines_expanded[silver_data_list].isnull().sum(axis=1)==0,"data_rank_colour"] = "silver"
df_turbines_expanded.loc[df_turbines_expanded[silver_data_list].isnull().sum(axis=1)==0,"data_rank"] = "silver"

# %%
df_turbines_expanded[gold_data_list].isnull().sum(axis=1)

df_turbines_expanded.loc[df_turbines_expanded[gold_data_list].isnull().sum(axis=1)==0,"data_rank_colour"] = "gold"
df_turbines_expanded.loc[df_turbines_expanded[gold_data_list].isnull().sum(axis=1)==0,"data_rank"] = "gold"

# %%
map = plot_points(df_turbines_expanded)

show(map)
# Out:
#   <div id="cca612ac-df4a-45d1-9a83-1ce8f7b6602e" data-root-id="p1007" style="display: contents;"></div>

# %%
for item in df_turbines_expanded.columns:
    print(item)
# Out:
# Unnamed_ 0
# type
# id
# lat
# lon
# generator_method
# generator_source
# operator
# power
# generator_output_electricity
# generator_type
# name
# source
# generator_model
# height
# operator_wikidata
# manufacturer
# model
# rotor_diameter
# start_date
# height_hub
# data_rank_colour
# data_rank
# x
# y
# coordinates
# auto_line_color

# %%
df_turbines_expanded.to_csv("WhiteleeWTGs.csv")
