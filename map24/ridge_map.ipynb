# %%
import matplotlib
from ridge_map import RidgeMap

# %%
# Very cool line font
# https://fonts.google.com/specimen/Linefont?preview.text=Guernsey

# %%
RidgeMap().plot_map()
# Out:
# <Axes: >

# %%
rm = RidgeMap((11.098251,47.264786,11.695633,47.453630))
values = rm.get_elevation_data(num_lines=150)
values=rm.preprocess(
    values=values,
    lake_flatness=2,
    water_ntile=10,
    vertical_ratio=240)
rm.plot_map(values=values,
            label='Karwendelgebirge',
            label_y=0.1,
            label_x=0.55,
            label_size=40,
            linewidth=1)
# Out:
# 4 2884802
# <Axes: >

# %%
rm = RidgeMap((-2.72,49.37,-2.13,49.76))

values = rm.get_elevation_data(num_lines=400)

values=rm.preprocess(
    values=values,
    lake_flatness=2,
    water_ntile=2,
    vertical_ratio=100)

ridges = rm.plot_map(values=values,
            label='The Baliwick of Guernsey',
            label_y=0.5,
            label_x=0.55,
            label_size=40,
            linewidth=1,
            background_color='white',
            line_color='black')

# %%
rm = RidgeMap((-2.69,49.4,-2.49,49.52))
values = rm.get_elevation_data(num_lines=200)
values=rm.preprocess(
    values=values,
    lake_flatness=1,
    water_ntile=2,
    vertical_ratio=100)
rm.plot_map(values=values,
            label='Guernsey',
            label_y=0.75,
            label_x=0.2,
            label_size=50,
            linewidth=4,
            background_color='white',
            line_color='black')
# Out:
# <Axes: >

# %%
rm = RidgeMap((-2.69,49.39,-2.32,49.52))
values = rm.get_elevation_data(num_lines=100)
values=rm.preprocess(
    values=values,
    lake_flatness=2,
    water_ntile=2,
    vertical_ratio=100)
rm.plot_map(values=values,
            label=None,
            label_y=0.75,
            label_x=0.2,
            label_size=50,
            linewidth=5,
            background_color='white',
            line_color='black')
# Out:
# <Axes: >
